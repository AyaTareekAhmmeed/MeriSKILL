# %% [markdown]
# # HR ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\10-Me22\Downloads\Project 3 - HR Analytics-20231017T183733Z-001\Project 3 - HR Analytics\Data P3 MeriSKILL\HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.describe(include='object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['WorkLifeBalance'].value_counts()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
df.rename(columns={'WorkLifeBalanceRate': 'WorkLifeBalanceSatisfaction'}, inplace=True)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df['RelationshipSatisfaction'].value_counts()
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %% [markdown]
# # Descriptive Statistics

# %%
#How many employees have left the company (Attrition)?
attrition_counts = df['Attrition'].value_counts()
print(attrition_counts)
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# 237 employees have left the company

# %%
#What is the average monthly income of employees?
average_monthly_income = df['MonthlyIncome'].mean()
print(average_monthly_income)
# Out:
# 6502.931292517007

# %% [markdown]
# Average monthly income of employee = 6503

# %%
#What is the average distance from home for employees?
average_distance_from_home = df['DistanceFromHome'].mean()
print(average_distance_from_home)
# Out:
# 9.19251700680272

# %% [markdown]
# Average distance from home for employee = 9

# %%
#What is the most common education field among employees?
common_education_field = df['EducationField'].value_counts().idxmax()
print(common_education_field)
# Out:
# Life Sciences

# %% [markdown]
# The most common education field among employees is Life Sciences

# %% [markdown]
# # Attrition Analysis

# %%
#What factors are associated with higher attrition rates?
sns.set(style="whitegrid")
factors = ['Age', 'MonthlyIncome', 'DistanceFromHome', 'JobSatisfaction', 'WorkLifeBalanceSatisfaction', 'JobInvolvement']

for factor in factors:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Attrition', y=factor, data=df)
    plt.title(f'Attrition vs {factor}')
    plt.show()

# %%
#Are employees who work overtime more likely to leave the company?
plt.figure(figsize=(6, 4))
sns.countplot(x='OverTime', hue='Attrition', data=df)
plt.title('Attrition vs Overtime')
plt.show()

# %%
#How does job satisfaction relate to attrition?
plt.figure(figsize=(6, 4))
sns.countplot(x='JobSatisfaction', hue='Attrition', data=df)
plt.title('Attrition vs Job Satisfaction')
plt.show()

# %%
#Does the department or job role impact attrition rates?
plt.figure(figsize=(8, 6))
sns.countplot(x='Department', hue='Attrition', data=df)
plt.title('Attrition vs Department')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='JobRole', hue='Attrition', data=df)
plt.xticks(rotation=90)
plt.title('Attrition vs Job Role')
plt.show()

# %% [markdown]
# # Promotions and Career Progression

# %%
#How long do employees typically stay in their current roles?
average_years_in_current_role = df['YearsInCurrentRole'].mean()
print(f"Average years in current role: {average_years_in_current_role:.2f} years")
# Out:
# Average years in current role: 4.23 years

# %%
#How many years on average since the last promotion?
average_years_since_last_promotion = df['YearsSinceLastPromotion'].mean()
print(f"Average years since last promotion: {average_years_since_last_promotion:.2f} years")
# Out:
# Average years since last promotion: 2.19 years

# %%
#Do certain job roles have higher rates of career progression?
plt.figure(figsize=(10, 6))
sns.barplot(x='YearsInCurrentRole', y='JobRole', data=df, ci=None)
plt.xlabel('Average Years in Current Role')
plt.ylabel('Job Role')
plt.title('Average Years in Current Role by Job Role')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\10-Me22\AppData\Local\Temp\ipykernel_4028\1796914058.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='YearsInCurrentRole', y='JobRole', data=df, ci=None)

# %% [markdown]
# # Management and Leadership

# %%
#How long do employees typically stay with their current managers?
average_years_with_curr_manager = df['YearsWithCurrManager'].mean()
print(f"Average years with current manager: {average_years_with_curr_manager:.2f} years")
# Out:
# Average years with current manager: 4.12 years

# %%
#Are employees with more years of experience more likely to become managers?
plt.figure(figsize=(8, 6))
sns.scatterplot(x='YearsAtCompany', y='JobLevel', data=df)
plt.xlabel('Years at Company')
plt.ylabel('Job Level')
plt.title('Years at Company vs. Job Level')
plt.show()

# %% [markdown]
# # Training and Development

# %%
#How many training times did employees have last year?
total_training_last_year = df['TrainingTimesLastYear'].sum()
print(f"Total training times last year: {total_training_last_year}")
# Out:
# Total training times last year: 4115

# %%
#Is there a correlation between training and performance?
correlation_matrix = df[['TrainingTimesLastYear', 'PerformanceRating']].corr()

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation between Training and Performance')
plt.show()

# %%
#Are employees with more training more likely to stay?
plt.figure(figsize=(6, 4))
sns.countplot(x='TrainingTimesLastYear', hue='Attrition', data=df)
plt.title('Attrition vs. Training Times Last Year')
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr(), annot= True)
plt.title('Correlation')
plt.show()
# Out:
# C:\Users\10-Me22\AppData\Local\Temp\ipykernel_4028\1862138757.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot= True)

# %%
#high correlation between joblevel and monthly income & total working years and job level also with monthly incom & total working year with age& years at company with years in current role and years with current manager
